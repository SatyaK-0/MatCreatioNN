# %%
import numpy as np
import re
from collections import Counter

# Periodic table: List of all elements and their atomic numbers (proton counts)
periodic_table = [
    ("H", 1), ("He", 2), ("Li", 3), ("Be", 4), ("B", 5), ("C", 6), ("N", 7), ("O", 8),
    ("F", 9), ("Ne", 10), ("Na", 11), ("Mg", 12), ("Al", 13), ("Si", 14), ("P", 15), ("S", 16),
    ("Cl", 17), ("Ar", 18),("K", 19), ("Ca", 20), ("Sc", 21), ("Ti", 22), ("V", 23), ("Cr", 24),
    ("Mn", 25), ("Fe", 26), ("Co", 27), ("Ni", 28), ("Cu", 29), ("Zn", 30), ("Ga", 31), ("Ge", 32),
    ("As", 33), ("Se", 34), ("Br", 35), ("Kr", 36), ("Rb", 37), ("Sr", 38), ("Y", 39), ("Zr", 40),
    ("Nb", 41), ("Mo", 42), ("Tc", 43), ("Ru", 44), ("Rh", 45), ("Pd", 46), ("Ag", 47), ("Cd", 48),
    ("In", 49), ("Sn", 50), ("Sb", 51),('Te', 52), ("I", 53), ("Xe", 54), ("Cs", 55), ("Ba", 56), ("La", 57),
    ("Ce", 58), ("Pr", 59), ("Nd", 60), ("Pm", 61), ("Sm", 62), ("Eu", 63), ("Gd", 64), ("Tb", 65),
    ("Dy", 66), ("Ho", 67), ("Er", 68), ("Tm", 69), ("Yb", 70), ("Lu", 71), ("Hf", 72), ("Ta", 73),
    ("W", 74), ("Re", 75), ("Os", 76), ("Ir", 77), ("Pt", 78), ("Au", 79), ("Hg", 80), ("Tl", 81),
    ("Pb", 82), ("Bi", 83), ("Po", 84), ("At", 85), ("Rn", 86), ("Fr", 87), ("Ra", 88), ("Ac", 89),
    ("Th", 90), ("Pa", 91), ("U", 92), ("Np", 93), ("Pu", 94), ("Am", 95), ("Cm", 96), ("Bk", 97),
    ("Cf", 98), ("Es", 99), ("Fm", 100), ("Md", 101), ("No", 102), ("Lr", 103), ("Rf", 104), ("Db", 105),
    ("Sg", 106), ("Bh", 107), ("Hs", 108), ("Mt", 109), ("Ds", 110), ("Rg", 111), ("Cn", 112), ("Nh", 113),
    ("Fl", 114), ("Mc", 115), ("Lv", 116), ("Ts", 117), ("Og", 118)
]

# Create a dictionary of elements and their atomic numbers
atomic_numbers = {element: atomic_number for element, atomic_number in periodic_table}

def parse_formula(formula):
    # Regular expression to extract molecules and their counts
    pattern = r'([A-Za-z]+)(\d*)'  # Matches element name and its count

    # Find all element-count pairs in the formula
    compounds = re.findall(pattern, formula)

    # Create a dictionary to count occurrences of each element
    element_counts = Counter()

    for compound in compounds:
        element, count = compound
        count = int(count) if count else 1  # Default count is 1 if not specified
        element_counts[element] += count

    # Prepare a list of all elements in the periodic table with their counts (0 if not in formula)
    all_elements = []
    for element, atomic_number in atomic_numbers.items():
        count = element_counts.get(element, 0)
        #all_elements.append([element, count]) #ORIGINAL CODE
        all_elements.append([count]) #TRUE CODE,
    # Sort by atomic number (proton count)

    #all_elements.sort(key=lambda x: atomic_numbers[x[0]])

    # Convert to a numpy array
    return np.array(all_elements, dtype=object)

# Example usage with glucose (C6H12O6)
#formula = "C6H11O6"
#compound_array = parse_formula(formula)

#print(compound_array)

# %%
import math

# %%
'''mass = np.array([[]])
for i in range (118):
  mass = np.append(mass,[[1/(2*(i+1))]])

massINV = mass.reshape(118,1)'''
# Out:
# 'mass = np.array([[]])\nfor i in range (118):\n  mass = np.append(mass,[[1/(2*(i+1))]])\n\nmassINV = mass.reshape(118,1)'

# %%
'''molecular_weights = [
    1.008, 4.0026, 6.94, 9.0122, 10.81, 12.011, 14.007, 15.999, 18.998, 20.180, 22.990, 24.305, 26.982, 28.085, 30.974, 32.06, 35.45, 39.948, 39.098, 40.078, 44.956, 47.867, 50.9415, 52.00, 54.938044, 55.845, 58.933194, 58.6934, 62.9296, 64.938044, 69.723, 72.63, 74.921595, 78.971, 79.904, 83.798, 85.4678, 87.62, 88.90584, 91.224, 92.90638, 95.95, 98.0, 101.07, 102.90550, 106.42, 107.8682, 112.414, 114.818, 118.710, 121.76, 127.60, 126.90447, 131.293, 132.90545196, 137.327, 138.90547, 140.116, 140.90766, 144.242, 145.0, 150.36, 151.964, 157.25, 158.92535, 162.500, 164.93033, 167.259, 168.93422, 173.04, 174.9668, 178.49, 180.94788, 183.84, 186.207, 190.23, 192.217, 195.078, 196.966569, 200.592, 204.38, 207.2, 208.98040, 209.98287, 222.0, 223.0, 226.0254, 227.0278, 232.0377, 231.03588, 238.02891, 237.0482, 242.0287, 243.0, 247.0, 251.0, 252.0, 257.0, 258.0, 259.0, 262.0, 267.0, 270.0, 271.0, 270.0, 277.0, 276.0, 281.0, 280.0, 285.0, 286.0, 289.0, 290.0, 293.0, 294.0, 294.0, 298.0, 299.0, 302.0, 305.0, 306.0, 307.0, 308.0, 311.0, 312.0, 315.0, 316.0, 319.0, 320.0, 323.0, 324.0, 327.0, 328.0, 331.0, 332.0, 335.0, 336.0, 339.0, 340.0
]

# Convert the list to a numpy array and reshape it to (118, 1)
molecular_weights_array = np.array(molecular_weights).reshape(118, 1)

# Show the array
print(molecular_weights_array)'''
# Out:
# 'molecular_weights = [\n    1.008, 4.0026, 6.94, 9.0122, 10.81, 12.011, 14.007, 15.999, 18.998, 20.180, 22.990, 24.305, 26.982, 28.085, 30.974, 32.06, 35.45, 39.948, 39.098, 40.078, 44.956, 47.867, 50.9415, 52.00, 54.938044, 55.845, 58.933194, 58.6934, 62.9296, 64.938044, 69.723, 72.63, 74.921595, 78.971, 79.904, 83.798, 85.4678, 87.62, 88.90584, 91.224, 92.90638, 95.95, 98.0, 101.07, 102.90550, 106.42, 107.8682, 112.414, 114.818, 118.710, 121.76, 127.60, 126.90447, 131.293, 132.90545196, 137.327, 138.90547, 140.116, 140.90766, 144.242, 145.0, 150.36, 151.964, 157.25, 158.92535, 162.500, 164.93033, 167.259, 168.93422, 173.04, 174.9668, 178.49, 180.94788, 183.84, 186.207, 190.23, 192.217, 195.078, 196.966569, 200.592, 204.38, 207.2, 208.98040, 209.98287, 222.0, 223.0, 226.0254, 227.0278, 232.0377, 231.03588, 238.02891, 237.0482, 242.0287, 243.0, 247.0, 251.0, 252.0, 257.0, 258.0, 259.0, 262.0, 267.0, 270.0, 271.0, 270.0, 277.0, 276.0, 281.0, 280.0, 285.0, 286.0, 289.0, 290.0, 293.0, 2
# ...

# %%
'''molecular_weights = [
    1.008, 4.0026, 6.94, 9.0122, 10.81, 12.011, 14.007, 15.999, 18.998, 20.180, 22.990, 24.305, 26.982, 28.085, 30.974,
    32.06, 35.45, 39.948, 39.098, 40.078, 44.956, 47.867, 50.9415, 52.00, 54.938044, 55.845, 58.933194, 58.6934, 62.9296,
    64.938044, 69.723, 72.63, 74.921595, 78.971, 79.904, 83.798, 85.4678, 87.62, 88.90584, 91.224, 92.90638, 95.95, 98.0,
    101.07, 102.90550, 106.42, 107.8682, 112.414, 114.818, 118.710, 121.76, 127.60, 126.90447, 131.293, 132.90545196,
    137.327, 138.90547, 140.116, 140.90766, 144.242, 145.0, 150.36, 151.964, 157.25, 158.92535, 162.500, 164.93033,
    167.259, 168.93422, 173.04, 174.9668, 178.49, 180.94788, 183.84, 186.207, 190.23, 192.217, 195.078, 196.966569,
    200.592, 204.38, 207.2, 208.98040, 209.98287, 222.0, 223.0, 226.0254, 227.0278, 232.0377, 231.03588, 238.02891,
    237.0482, 242.0287, 243.0, 247.0, 251.0, 252.0, 257.0, 258.0, 259.0, 262.0, 267.0, 270.0, 271.0, 270.0, 277.0,
    276.0, 281.0, 280.0, 285.0, 286.0, 289.0, 290.0, 293.0, 294.0, 294.0, 298.0, 299.0, 302.0, 305.0, 306.0, 307.0,
    308.0, 311.0, 312.0, 315.0, 316.0, 319.0, 320.0, 323.0, 324.0, 327.0, 328.0, 331.0, 332.0, 335.0, 336.0, 339.0,
    340.0
]

# Convert the list to a numpy array and reshape it to (118, 1)
molecular_weights_array = np.array(molecular_weights).reshape(118, 1)

# Show the array
print(molecular_weights_array)'''
# Out:
# 'molecular_weights = [\n    1.008, 4.0026, 6.94, 9.0122, 10.81, 12.011, 14.007, 15.999, 18.998, 20.180, 22.990, 24.305, 26.982, 28.085, 30.974,\n    32.06, 35.45, 39.948, 39.098, 40.078, 44.956, 47.867, 50.9415, 52.00, 54.938044, 55.845, 58.933194, 58.6934, 62.9296,\n    64.938044, 69.723, 72.63, 74.921595, 78.971, 79.904, 83.798, 85.4678, 87.62, 88.90584, 91.224, 92.90638, 95.95, 98.0,\n    101.07, 102.90550, 106.42, 107.8682, 112.414, 114.818, 118.710, 121.76, 127.60, 126.90447, 131.293, 132.90545196,\n    137.327, 138.90547, 140.116, 140.90766, 144.242, 145.0, 150.36, 151.964, 157.25, 158.92535, 162.500, 164.93033,\n    167.259, 168.93422, 173.04, 174.9668, 178.49, 180.94788, 183.84, 186.207, 190.23, 192.217, 195.078, 196.966569,\n    200.592, 204.38, 207.2, 208.98040, 209.98287, 222.0, 223.0, 226.0254, 227.0278, 232.0377, 231.03588, 238.02891,\n    237.0482, 242.0287, 243.0, 247.0, 251.0, 252.0, 257.0, 258.0, 259.0, 262.0, 267.0, 270.0, 271.0, 270.0, 277.0,\n    276.0, 281.0, 280
# ...

# %%
'''import numpy as np

# Correct list of molecular weights for the first 118 elements
molecular_weights = [
    1.008, 4.0026, 6.94, 9.0122, 10.81, 12.011, 14.007, 15.999, 18.998, 20.180, 22.990, 24.305, 26.982, 28.085, 30.974,
    32.06, 35.45, 39.948, 39.098, 40.078, 44.956, 47.867, 50.9415, 52.00, 54.938044, 55.845, 58.933194, 58.6934, 62.9296,
    64.938044, 69.723, 72.63, 74.921595, 78.971, 79.904, 83.798, 85.4678, 87.62, 88.90584, 91.224, 92.90638, 95.95, 98.0,
    101.07, 102.90550, 106.42, 107.8682, 112.414, 114.818, 118.710, 121.76, 127.60, 126.90447, 131.293, 132.90545196,
    137.327, 138.90547, 140.116, 140.90766, 144.242, 145.0, 150.36, 151.964, 157.25, 158.92535, 162.500, 164.93033,
    167.259, 168.93422, 173.04, 174.9668, 178.49, 180.94788, 183.84, 186.207, 190.23, 192.217, 195.078, 196.966569,
    200.592, 204.38, 207.2, 208.98040, 209.98287, 222.0, 223.0, 226.0254, 227.0278, 232.0377, 231.03588, 238.02891,
    237.0482, 242.0287, 243.0, 247.0, 251.0, 252.0, 257.0, 258.0, 259.0, 262.0, 267.0, 270.0, 271.0, 270.0, 277.0,
    276.0, 281.0, 280.0, 285.0, 286.0, 289.0, 290.0, 293.0, 294.0, 294.0, 298.0, 299.0, 302.0, 305.0, 306.0, 307.0
]

# Convert the list to a numpy array and reshape it to (118, 1)
molecular_weights_array = np.array(molecular_weights).reshape(118, 1)

# Show the array
print(molecular_weights_array)'''
# Out:
# 'import numpy as np\n\n# Correct list of molecular weights for the first 118 elements\nmolecular_weights = [\n    1.008, 4.0026, 6.94, 9.0122, 10.81, 12.011, 14.007, 15.999, 18.998, 20.180, 22.990, 24.305, 26.982, 28.085, 30.974,\n    32.06, 35.45, 39.948, 39.098, 40.078, 44.956, 47.867, 50.9415, 52.00, 54.938044, 55.845, 58.933194, 58.6934, 62.9296,\n    64.938044, 69.723, 72.63, 74.921595, 78.971, 79.904, 83.798, 85.4678, 87.62, 88.90584, 91.224, 92.90638, 95.95, 98.0,\n    101.07, 102.90550, 106.42, 107.8682, 112.414, 114.818, 118.710, 121.76, 127.60, 126.90447, 131.293, 132.90545196,\n    137.327, 138.90547, 140.116, 140.90766, 144.242, 145.0, 150.36, 151.964, 157.25, 158.92535, 162.500, 164.93033,\n    167.259, 168.93422, 173.04, 174.9668, 178.49, 180.94788, 183.84, 186.207, 190.23, 192.217, 195.078, 196.966569,\n    200.592, 204.38, 207.2, 208.98040, 209.98287, 222.0, 223.0, 226.0254, 227.0278, 232.0377, 231.03588, 238.02891,\n    237.0482, 242.0287, 243.0, 247.0, 251.0, 252.0,
# ...

# %%
'''import numpy as np

# Correct molecular weights for the first 118 elements
molecular_weights = [
    1.008, 4.0026, 6.94, 9.0122, 10.81, 12.011, 14.007, 15.999, 18.998, 20.180, 22.990, 24.305, 26.982, 28.085, 30.974,
    32.06, 35.45, 39.948, 39.098, 40.078, 44.956, 47.867, 50.9415, 52.00, 54.938044, 55.845, 58.933194, 58.6934, 62.9296,
    64.938044, 69.723, 72.63, 74.921595, 78.971, 79.904, 83.798, 85.4678, 87.62, 88.90584, 91.224, 92.90638, 95.95, 98.0,
    101.07, 102.90550, 106.42, 107.8682, 112.414, 114.818, 118.710, 121.76, 127.60, 126.90447, 131.293, 132.90545196,
    137.327, 138.90547, 140.116, 140.90766, 144.242, 145.0, 150.36, 151.964, 157.25, 158.92535, 162.500, 164.93033,
    167.259, 168.93422, 173.04, 174.9668, 178.49, 180.94788, 183.84, 186.207, 190.23, 192.217, 195.078, 196.966569,
    200.592, 204.38, 207.2, 208.98040, 209.98287, 222.0, 223.0, 226.0254, 227.0278, 232.0377, 231.03588, 238.02891,
    237.0482, 242.0287, 243.0, 247.0, 251.0, 252.0, 257.0, 258.0, 259.0, 262.0, 267.0, 270.0, 271.0, 270.0, 277.0,
    276.0, 281.0, 280.0, 285.0, 286.0, 289.0, 290.0, 293.0, 294.0, 294.0, 298.0, 299.0, 302.0, 305.0, 306.0
]

# Convert the list to a numpy array and reshape it to (118, 1)
molecular_weights_array = np.array(molecular_weights).reshape(118, 1)

# Show the array
print(molecular_weights_array)
'''
# Out:
# 'import numpy as np\n\n# Correct molecular weights for the first 118 elements\nmolecular_weights = [\n    1.008, 4.0026, 6.94, 9.0122, 10.81, 12.011, 14.007, 15.999, 18.998, 20.180, 22.990, 24.305, 26.982, 28.085, 30.974,\n    32.06, 35.45, 39.948, 39.098, 40.078, 44.956, 47.867, 50.9415, 52.00, 54.938044, 55.845, 58.933194, 58.6934, 62.9296,\n    64.938044, 69.723, 72.63, 74.921595, 78.971, 79.904, 83.798, 85.4678, 87.62, 88.90584, 91.224, 92.90638, 95.95, 98.0,\n    101.07, 102.90550, 106.42, 107.8682, 112.414, 114.818, 118.710, 121.76, 127.60, 126.90447, 131.293, 132.90545196,\n    137.327, 138.90547, 140.116, 140.90766, 144.242, 145.0, 150.36, 151.964, 157.25, 158.92535, 162.500, 164.93033,\n    167.259, 168.93422, 173.04, 174.9668, 178.49, 180.94788, 183.84, 186.207, 190.23, 192.217, 195.078, 196.966569,\n    200.592, 204.38, 207.2, 208.98040, 209.98287, 222.0, 223.0, 226.0254, 227.0278, 232.0377, 231.03588, 238.02891,\n    237.0482, 242.0287, 243.0, 247.0, 251.0, 252.0, 257.0, 
# ...

# %%
'''import numpy as np

# Correct molecular weights for the first 118 elements
molecular_weights = [
    1.008, 4.0026, 6.94, 9.0122, 10.81, 12.011, 14.007, 15.999, 18.998, 20.180, 22.990, 24.305, 26.982, 28.085, 30.974,
    32.06, 35.45, 39.948, 39.098, 40.078, 44.956, 47.867, 50.9415, 52.00, 54.938044, 55.845, 58.933194, 58.6934, 62.9296,
    64.938044, 69.723, 72.63, 74.921595, 78.971, 79.904, 83.798, 85.4678, 87.62, 88.90584, 91.224, 92.90638, 95.95, 98.0,
    101.07, 102.90550, 106.42, 107.8682, 112.414, 114.818, 118.710, 121.76, 127.60, 126.90447, 131.293, 132.90545196,
    137.327, 138.90547, 140.116, 140.90766, 144.242, 145.0, 150.36, 151.964, 157.25, 158.92535, 162.500, 164.93033,
    167.259, 168.93422, 173.04, 174.9668, 178.49, 180.94788, 183.84, 186.207, 190.23, 192.217, 195.078, 196.966569,
    200.592, 204.38, 207.2, 208.98040, 209.98287, 222.0, 223.0, 226.0254, 227.0278, 232.0377, 231.03588, 238.02891,
    237.0482, 242.0287, 243.0, 247.0, 251.0, 252.0, 257.0, 258.0, 259.0, 262.0, 267.0, 270.0, 271.0, 270.0, 277.0,
    276.0, 281.0, 280.0, 285.0, 286.0, 289.0, 290.0, 293.0, 294.0, 294.0, 298.0, 299.0, 302.0, 305.0, 306.0, 307.0
]

# Ensure the list has exactly 118 elements
assert len(molecular_weights) == 118, "The list has more or fewer than 118 elements."

# Convert the list to a numpy array and reshape it to (118, 1)
molecular_weights_array = np.array(molecular_weights).reshape(118, 1)

# Show the array
print(molecular_weights_array)
'''
# Out:
# 'import numpy as np\n\n# Correct molecular weights for the first 118 elements\nmolecular_weights = [\n    1.008, 4.0026, 6.94, 9.0122, 10.81, 12.011, 14.007, 15.999, 18.998, 20.180, 22.990, 24.305, 26.982, 28.085, 30.974,\n    32.06, 35.45, 39.948, 39.098, 40.078, 44.956, 47.867, 50.9415, 52.00, 54.938044, 55.845, 58.933194, 58.6934, 62.9296,\n    64.938044, 69.723, 72.63, 74.921595, 78.971, 79.904, 83.798, 85.4678, 87.62, 88.90584, 91.224, 92.90638, 95.95, 98.0,\n    101.07, 102.90550, 106.42, 107.8682, 112.414, 114.818, 118.710, 121.76, 127.60, 126.90447, 131.293, 132.90545196,\n    137.327, 138.90547, 140.116, 140.90766, 144.242, 145.0, 150.36, 151.964, 157.25, 158.92535, 162.500, 164.93033,\n    167.259, 168.93422, 173.04, 174.9668, 178.49, 180.94788, 183.84, 186.207, 190.23, 192.217, 195.078, 196.966569,\n    200.592, 204.38, 207.2, 208.98040, 209.98287, 222.0, 223.0, 226.0254, 227.0278, 232.0377, 231.03588, 238.02891,\n    237.0482, 242.0287, 243.0, 247.0, 251.0, 252.0, 257.0, 
# ...

# %%
'''molecular_weights = [
    1.008, 4.0026, 6.94, 9.0122, 10.81, 12.011, 14.007, 15.999, 18.998, 20.180, 22.990, 24.305, 26.982, 28.085, 30.974,
    32.06, 35.45, 39.948, 39.098, 40.078, 44.956, 47.867, 50.9415, 52.00, 54.938044, 55.845, 58.933194, 58.6934, 62.9296,
    64.938044, 69.723, 72.63, 74.921595, 78.971, 79.904, 83.798, 85.4678, 87.62, 88.90584, 91.224, 92.90638, 95.95, 98.0,
    101.07, 102.90550, 106.42, 107.8682, 112.414, 114.818, 118.710, 121.76, 127.60, 126.90447, 131.293, 132.90545196,
    137.327, 138.90547, 140.116, 140.90766, 144.242, 145.0, 150.36, 151.964, 157.25, 158.92535, 162.500, 164.93033,
    167.259, 168.93422, 173.04, 174.9668, 178.49, 180.94788, 183.84, 186.207, 190.23, 192.217, 195.078, 196.966569,
    200.592, 204.38, 207.2, 208.98040, 209.98287, 222.0, 223.0, 226.0254, 227.0278, 232.0377, 231.03588, 238.02891,
    237.0482, 242.0287, 243.0, 247.0, 251.0, 252.0, 257.0, 258.0, 259.0, 262.0, 267.0, 270.0, 271.0, 270.0, 277.0,
    276.0, 281.0, 280.0, 285.0, 286.0, 289.0, 290.0, 293.0, 294.0, 294.0, 298.0, 299.0, 302.0, 305.0, 306.0
]

# Verify that the list has exactly 118 elements
print("Length of the list:", len(molecular_weights))  # This should print 118

# Convert the list to a numpy array and reshape it to (118, 1)
molecular_weights_array = np.array(molecular_weights).reshape(118, 1)

# Show the array
print(molecular_weights_array)'''
# Out:
# 'molecular_weights = [\n    1.008, 4.0026, 6.94, 9.0122, 10.81, 12.011, 14.007, 15.999, 18.998, 20.180, 22.990, 24.305, 26.982, 28.085, 30.974,\n    32.06, 35.45, 39.948, 39.098, 40.078, 44.956, 47.867, 50.9415, 52.00, 54.938044, 55.845, 58.933194, 58.6934, 62.9296,\n    64.938044, 69.723, 72.63, 74.921595, 78.971, 79.904, 83.798, 85.4678, 87.62, 88.90584, 91.224, 92.90638, 95.95, 98.0,\n    101.07, 102.90550, 106.42, 107.8682, 112.414, 114.818, 118.710, 121.76, 127.60, 126.90447, 131.293, 132.90545196,\n    137.327, 138.90547, 140.116, 140.90766, 144.242, 145.0, 150.36, 151.964, 157.25, 158.92535, 162.500, 164.93033,\n    167.259, 168.93422, 173.04, 174.9668, 178.49, 180.94788, 183.84, 186.207, 190.23, 192.217, 195.078, 196.966569,\n    200.592, 204.38, 207.2, 208.98040, 209.98287, 222.0, 223.0, 226.0254, 227.0278, 232.0377, 231.03588, 238.02891,\n    237.0482, 242.0287, 243.0, 247.0, 251.0, 252.0, 257.0, 258.0, 259.0, 262.0, 267.0, 270.0, 271.0, 270.0, 277.0,\n    276.0, 281.0, 280
# ...

# %%
molecular_weights = {
    "H": 1.00794,
    "He": 4.002602,
    "Li": 6.941,
    "Be": 9.012182,
    "B": 10.811,
    "C": 12.0107,
    "N": 14.0067,
    "O": 15.9994,
    "F": 18.9984032,
    "Ne": 20.1797,
    "Na": 22.98976928,
    "Mg": 24.305,
    "Al": 26.9815386,
    "Si": 28.0855,
    "P": 30.973762,
    "S": 32.065,
    "Cl": 35.453,
    "Ar": 39.948,
    "K": 39.0983,
    "Ca": 40.078,
    "Sc": 44.955912,
    "Ti": 47.867,
    "V": 50.9415,
    "Cr": 51.9961,
    "Mn": 54.938045,
    "Fe": 55.845,
    "Co": 58.933195,
    "Ni": 58.6934,
    "Cu": 63.546,
    "Zn": 65.409,
    "Ga": 69.723,
    "Ge": 72.64,
    "As": 74.9216,
    "Se": 78.96,
    "Br": 79.904,
    "Kr": 83.798,
    "Rb": 85.4678,
    "Sr": 87.62,
    "Y": 88.90585,
    "Zr": 91.224,
    "Nb": 92.90638,
    "Mo": 95.94,
    "Tc": 98,
    "Ru": 101.07,
    "Rh": 102.9055,
    "Pd": 106.42,
    "Ag": 107.8682,
    "Cd": 112.411,
    "In": 114.818,
    "Sn": 118.71,
    "Sb": 121.760,
    "Te": 127.6,
    "I": 126.90447,
    "Xe": 131.293,
    "Cs": 132.9054519,
    "Ba": 137.327,
    "La": 138.90547,
    "Ce": 140.116,
    "Pr": 140.90765,
    "Nd": 144.242,
    "Pm": 145,
    "Sm": 150.36,
    "Eu": 151.964,
    "Gd": 157.25,
    "Tb": 158.92535,
    "Dy": 162.5,
    "Ho": 164.93032,
    "Er": 167.259,
    "Tm": 168.93421,
    "Yb": 173.04,
    "Lu": 174.967,
    "Hf": 178.49,
    "Ta": 180.9479,
    "W": 183.84,
    "Re": 186.207,
    "Os": 190.23,
    "Ir": 192.217,
    "Pt": 195.084,
    "Au": 196.966569,
    "Hg": 200.59,
    "Tl": 204.3833,
    "Pb": 207.2,
    "Bi": 208.9804,
    "Po": 209,
    "At": 210,
    "Rn": 222,
    "Fr": 223,
    "Ra": 226,
    "Ac": 227,
    "Th": 232.03806,
    "Pa": 231.03588,
    "U": 238.02891,
    "Np": 237,
    "Pu": 244,
    "Am": 243,
    "Cm": 247,
    "Bk": 247,
    "Cf": 251,
    "Es": 252,
    "Fm": 257,
    "Md": 258,
    "No": 259,
    "Lr": 262,
    "Rf": 267,
    "Db": 268,
    "Sg": 271,
    "Bh": 272,
    "Hs": 270,
    "Mt": 276,
    "Ds": 281,
    "Rg": 280,
    "Cn": 285,
    "Nh": 284,
    "Fl": 289,
    "Mc": 288,
    "Lv": 293,
    "Ts": 294,
    "Og": 294
}

# Create a list of element symbols
element_symbols = list(molecular_weights.keys())

# Create a NumPy array of molecular weights
molecular_weight_array = np.array([molecular_weights[symbol] for symbol in element_symbols])

# %%
molecular_weight_array = molecular_weight_array.reshape(118,1)

# %%
molecular_weight_arrayINV = molecular_weight_array.copy()
for i in range (118):
  molecular_weight_arrayINV[i] = (1/molecular_weight_array[i])

# %%
molecular_weight_arrayINV
# Out:
# array([[0.99212255],
#        [0.24983748],
#        [0.14407146],
#        [0.11096092],
#        [0.09249838],
#        [0.08325909],
#        [0.0713944 ],
#        [0.06250234],
#        [0.052636  ],
#        [0.04955475],
#        [0.04349761],
#        [0.0411438 ],
#        [0.03706238],
#        [0.03560556],
#        [0.03228539],
#        [0.03118665],
#        [0.02820636],
#        [0.02503254],
#        [0.02557656],
#        [0.02495134],
#        [0.02224402],
#        [0.02089122],
#        [0.01963036],
#        [0.01923221],
#        [0.01820232],
#        [0.01790671],
#        [0.01696837],
#        [0.01703769],
#        [0.01573663],
#        [0.01528842],
#        [0.01434247],
#        [0.01376652],
#        [0.01334729],
#        [0.01266464],
#        [0.01251502],
#        [0.01193346],
#        [0.01170031],
#        [0.01141292],
#        [0.01124785],
#        [0.01096203],
#        [0.01076352],
#        [0.01042318],
#        [0.01020408],
# ...

# %%
#mass[0]=1

# %%
def calccost(formula):
  compound_array=parse_formula(formula)
  value = np.array([[1.39],[24.0],[83.5],[857],[3.68],[0.122],[0.14],[0.154],[2],[240],[3],[2.32],[1.79],[1.70],[2.69],[0.0926],[0.082],[0.931],[12.85],[2.28],
                  [3460],[11.4],[371],[9.40],[1.82],[0.424],[32.8],[13.9],[6.00],[2.55],[148],[962],[1.1545],[21.4],[4.39], [290],[15500], [6.605],[31.0],[36.4],
                  [73.5],[40.1],[100000],[10500],[147000],[49500],[521],[2.73],[167],[18.7],[5.79],[63.5],[35],[1800],[61800],[0.2605],[4.86],[4.64],[103],[57.5],
                  [460000],[13.9],[31.4],[28.6],[658],[307],[57.1],[26.4],[3000],[17.1],[643],[900],[305],[35.3],[3580],[12000],[55850],[27800],[75430],[30.2],
                  [4200],[2.00],[6.36],[49.2*10**12],[10^13],[10^13],[10**13],[-500],[29*10*812],[287],[10**13],[101],[660000],[6490000],[728000],[185000000],[185*10**9],[60.0*10**9],[10^13],[10**13],
                  [10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13]])
  cost = np.multiply(compound_array,value)
  #cost = np.multiply(cost,molecular_weight_array)
  #final_cost=np.sum(cost)
  #final_cost = math.trunc(final_cost * 1000) / 1000
  return cost

# %%
def calccostSum(calccost):
  step1 = np.multiply(calccost,molecular_weight_array)
  step1 = step1/(6.022*10**23)
  step1 = np.sum(step1)
  return step1

# %%
costCalc = calccost('H2')

# %%
print(calccostSum(costCalc))
# Out:
# 4.653060777150449e-24

# %%
def MassOfForm(formula):
  compound_array=parse_formula(formula)
  massVect = np.multiply(compound_array,molecular_weight_array)
  massSum = np.sum(massVect)
  return massSum

# %%
def FinCostPKg(formula):
  div = 1 #Change if formula seems different
  cost = calccostSum(calccost(formula))
  mass = MassOfForm(formula)
  ratio = np.divide(cost,mass)
  costPKg = np.divide(np.multiply(ratio,6.022*10**23),div)

  #print(ratio)
  #print(costPKg)
  return costPKg

# %%
FinCostPKg('H2')
# Out:
# 1.3900000000000001

# %%
#mass

# %%
#mult = np.zeros([117,1])

# %%
#zero = np.multiply(compound_array,mult)

# %%
'''value = np.array([[1.39],[24.0],[83.5],[857],[3.68],[0.122],[0.14],[0.154],[2],[240],[3],[2.32],[1.79],[1.70],[2.69],[0.0926],[0.082],[0.931],[12.85],[2.28],
                  [3460],[11.4],[371],[9.40],[1.82],[0.424],[32.8],[13.9],[6.00],[2.55],[148],[962],[1.1545],[21.4],[4.39], [290],[15500], [6.605],[31.0],[36.4],
                  [73.5],[40.1],[100000],[10500],[147000],[49500],[521],[2.73],[167],[18.7],[5.79],[63.5],[35],[1800],[61800],[0.2605],[4.86],[4.64],[103],[57.5],
                  [460000],[13.9],[31.4],[28.6],[658],[307],[57.1],[26.4],[3000],[17.1],[643],[900],[305],[35.3],[3580],[12000],[55850],[27800],[75430],[30.2],
                  [4200],[2.00],[6.36],[49.2*10**12],[10^13],[10^13],[10**13],[-500],[29*10*812],[287],[10**13],[101],[660000],[6490000],[728000],[185000000],[185*10**9],[60.0*10**9],[10^13],[10**13],
                  [10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13]])
value.shape
'''
# Out:
# 'value = np.array([[1.39],[24.0],[83.5],[857],[3.68],[0.122],[0.14],[0.154],[2],[240],[3],[2.32],[1.79],[1.70],[2.69],[0.0926],[0.082],[0.931],[12.85],[2.28],\n                  [3460],[11.4],[371],[9.40],[1.82],[0.424],[32.8],[13.9],[6.00],[2.55],[148],[962],[1.1545],[21.4],[4.39], [290],[15500], [6.605],[31.0],[36.4],\n                  [73.5],[40.1],[100000],[10500],[147000],[49500],[521],[2.73],[167],[18.7],[5.79],[63.5],[35],[1800],[61800],[0.2605],[4.86],[4.64],[103],[57.5],\n                  [460000],[13.9],[31.4],[28.6],[658],[307],[57.1],[26.4],[3000],[17.1],[643],[900],[305],[35.3],[3580],[12000],[55850],[27800],[75430],[30.2],\n                  [4200],[2.00],[6.36],[49.2*10**12],[10^13],[10^13],[10**13],[-500],[29*10*812],[287],[10**13],[101],[660000],[6490000],[728000],[185000000],[185*10**9],[60.0*10**9],[10^13],[10**13],\n                  [10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10**13],[10*
# ...

# %%
'''cost = np.multiply(compound_array,value)
cost.shape

final_cost=np.sum(cost)
final_cost'''
# Out:
# 'cost = np.multiply(compound_array,value)\ncost.shape\n\nfinal_cost=np.sum(cost)\nfinal_cost'

# %%
#print(zero)

# %% [markdown]
# ##Creating data about MOF cost in QMOF

# %%
import pandas as pd

# %%
cd ..
# Out:
# /

# %%
cd /content
# Out:
# /content

# %%
qmofcost = pd.read_csv('qmof_cost _used.csv')

# %%
qmofcost.head(10)
# Out:
#         qmof_id       info.formula
# 0  qmof-8a95c27      Ba2CuC6H14O16
# 1  qmof-019ba28  Cu12C36H56I16N4S4
# 2  qmof-830ed1c     Co4C48H32N8O16
# 3  qmof-5bd4a24     Co4C48H32N8O16
# 4  qmof-644aab4    Zn2C50H32N6O8S4
# 5  qmof-eaa4957     Ag6C10H10N4O12
# 6  qmof-ffa4c4a      Ag8C24H8N8O16
# 7  qmof-e813edb     Ag8C24H16N8O20
# 8  qmof-f364177   Zn4C104H76N12O20
# 9  qmof-d2e3fe6   Zn4C104H76N12O20

# %%
cifad=0

# %%
height = qmofcost.shape

# %%
print(height)
height[0]
# Out:
# (20375, 2)
# 20375

# %%
qmofcost['cost']=np.ones(shape=(height[0],1))

# %%
if (cifad == 0):
  for i in range(qmofcost.shape[0]):
    qmofcost.iat[i,2] = FinCostPKg(qmofcost.iat[i,1])
    print(qmofcost.iat[i,2])
  cifad = cifad+1
# Out:
# Streaming output truncated to the last 5000 lines.
# 2.0909633755391352
# 2.9577476949934898
# 14.543187907639133
# 2.289254948546908
# 1.0087735397005697
# 2.4234717466444904
# 0.40936038211744413
# 1.123080721086505
# 2.480045823619578
# 212.71322557034387
# 0.7602492082690199
# 8.721610507741268
# 1.3195369154921495
# 0.6682745741092692
# 2.1684149731970477
# 3.838166508325152
# 0.47056687896556254
# 0.6743680175198001
# 0.8769129274893993
# 0.8997172637942824
# 4.585246310298892
# 1.791401403903101
# 0.5847710743246356
# 13.242876050085115
# 17.38918426088034
# 0.39762202220273357
# 1.9339033917917958
# 10.847507262384536
# 0.5570889748077552
# 1.072532339183471
# 9.251916774992068
# 0.4821579907706306
# 0.7292147302223002
# 0.4810498560860901
# 0.6265571614458295
# 2.9360586293645996
# 1.4660995947128932
# 0.6112225736555412
# 36877.02987965255
# 0.7053270949066472
# 0.7297739081778629
# 8.065856189591285
# 3.493369641628142
# 0.5057246174843009
# 139.07786003014274
# ...

# %%
qmofcost.head(15)
# Out:
#          qmof_id       info.formula        cost
# 0   qmof-8a95c27      Ba2CuC6H14O16    0.239712
# 1   qmof-019ba28  Cu12C36H56I16N4S4   21.866613
# 2   qmof-830ed1c     Co4C48H32N8O16    6.517133
# 3   qmof-5bd4a24     Co4C48H32N8O16    6.517133
# 4   qmof-644aab4    Zn2C50H32N6O8S4    0.448444
# 5   qmof-eaa4957     Ag6C10H10N4O12  328.902933
# 6   qmof-ffa4c4a      Ag8C24H8N8O16  294.436733
# 7   qmof-e813edb     Ag8C24H16N8O20  281.183788
# 8   qmof-f364177   Zn4C104H76N12O20    0.481277
# 9   qmof-d2e3fe6   Zn4C104H76N12O20    0.481277
# 10  qmof-b5f254c     Pb2C28H24N8O12    0.879299
# 11  qmof-dc01ec5    Ag2C32H28N10O10  121.212433
# 12  qmof-de2f502        Cu4C8H16O12    2.845344
# 13  qmof-85a8986     Dy4C28H32N8O36  117.040857
# 14  qmof-780219c    La8C56H40N16O60    1.900769

# %%
csv_file_path = 'qmofcost_finalUpdate1-7-24.csv'
qmofcost.to_csv(csv_file_path, index='false')

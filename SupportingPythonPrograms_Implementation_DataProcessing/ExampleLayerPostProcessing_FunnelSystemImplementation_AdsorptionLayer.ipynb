# %%
import pandas as pd
import numpy as np

# %%
ASA = pd.read_csv('RootControl_ASA.csv', header = None)

Select = pd.read_csv('RootControl_Select.csv', header = None)

# %%
QKH = pd.read_csv('RootControl_QKH.csv', header = None)

# %%
ASA
# Out:
#                0            1
# 0   control_MOF5  2373.345215
# 1  Fe-Mil-53_NH2  2599.791016
# 2        MOF-808  1867.577148
# 3        PCN-222  2168.362305
# 4    PCN-224-Zr1  2236.382568
# 5    PCN-224-Zr2  2010.080688

# %%
ASAMax = 0
for i in range(ASA.shape[0]):
  if ASA.iat[i,1]> ASAMax:
    ASAMax = ASA.iat[i,1]
print(ASAMax)
# Out:
# 3251.96582

# %%
ASAMax=3251.96582

# %%
for i in range(ASA.shape[0]):
  ASA.iat[i,1] = ASA.iat[i,1]/ASAMax

# %%
SelectMax = 0
for i in range(ASA.shape[0]):
  if Select.iat[i,1]> SelectMax:
    SelectMax = Select.iat[i,1]
print(SelectMax)
# Out:
# 8.83568573

# %%
SelectMax=8.83568573

# %%
for i in range(ASA.shape[0]):
  Select.iat[i,1] = Select.iat[i,1]/SelectMax

# %%
import math

# %%
def bell_curve(x, a=1, b=-30, c=150):
    return a * math.exp(-((x - b)**2) / (2 * c**2))

# Given parameters
a = 0
b = -30
c = 150

# Compute F(-20)
#x = -20
#result = bell_curve(x, a, b, c)

# %%
for i in range(ASA.shape[0]):
  QKH.iat[i,1] = 1.002* min(bell_curve(QKH.iat[i,1]),bell_curve(-20))

# %%
QKH
# Out:
#                0         1
# 0   control_MOF5  0.999776
# 1  Fe-Mil-53_NH2  0.999776
# 2        MOF-808  0.999776
# 3        PCN-222  0.995477
# 4    PCN-224-Zr1  0.999776
# 5    PCN-224-Zr2  0.999776

# %%
#Sum.shape
# Out:
# (8662, 2)

# %%
Sum = QKH.copy(deep=True)

# %%
for i in range(ASA.shape[0]):
  Sum.iat[i,1] = QKH.iat[i,1] + ASA.iat[i,1] + Select.iat[i,1]

# %%
Sum
# Out:
#                0         1
# 0   control_MOF5  1.948603
# 1  Fe-Mil-53_NH2  1.993756
# 2        MOF-808  1.734939
# 3        PCN-222  1.721695
# 4    PCN-224-Zr1  1.752151
# 5    PCN-224-Zr2  1.630096

# %%
Sum.to_csv('Control_Dir5.csv')
